# %% [markdown]
# LangChain Intro !! ✌️✌️

# %% [markdown]
# IMPORTING PACKAGES

# %%
from dotenv import load_dotenv

from langchain_google_genai import ChatGoogleGenerativeAI
from langchain.agents import create_agent

load_dotenv()
# Out:
# True

# %% [markdown]
# CREATING SIMPLE AGENT 😶‍🌫️

# %%
def get_weather(city: str) -> str:
    """
    Get current weather information for a city.   
    """
    return f"The weather in {city} is Sunny ☀️"

def add(a: int, b: int) -> int:
    """
    Add two numbers.
    """
    return a + b

# ----------------------------------------------------------
# Gemini LLM
# ----------------------------------------------------------

model = ChatGoogleGenerativeAI(
    model="gemini-2.5-flash",
    temperature=0
)

# ----------------------------------------------------------
# Create Agent
# ----------------------------------------------------------

agent = create_agent(
    model=model,
    tools=[get_weather, add],
    system_prompt="""
    You are a helpful AI assistant.
    Use tools whenever required.
    """
)

# %% [markdown]
# CALLING AGENT

# %%
# ----------------------------------------------------------
# User Query
# ----------------------------------------------------------

response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "How is the weather in Delhi?"
            }
        ]
    }
)

# ----------------------------------------------------------
# Print Final Response
# ----------------------------------------------------------

print(response)


print(response["messages"][-1].content)


response = agent.invoke(
    {
        "messages": [
            {
                "role": "user",
                "content": "Add 32 and 2"
            }
        ]
    }
)
print(response)


print(response["messages"][-1].content)
# Out:
# {'messages': [HumanMessage(content='How is the weather in Delhi?', additional_kwargs={}, response_metadata={}, id='f4dae1cc-813a-41f1-b0eb-2d8c849da94d'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'get_weather', 'arguments': '{"city": "Delhi"}'}, '__gemini_function_call_thought_signatures__': {'463819f7-c8dd-4ea4-98ee-80d99513dfb0': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f2817-7696-7152-a995-f7666c930a09-0', tool_calls=[{'name': 'get_weather', 'args': {'city': 'Delhi'}, 'id': '463819f7-c8dd-4ea4-98ee-80d99513dfb0', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 111, 'output_tokens': 62, 'total_tokens': 173, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 47}}), ToolMessage(content='The weather in Delhi is Sunny ☀️', name='get_weather', id='a0a5b3b8-171c-4e52-94c9-33b402458230', tool_call_id='463819f7-c8dd-4ea4-98ee-80d99513dfb0'), AIMessage(content='The weather in Delhi is Sunny ☀️', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f2817-7a9f-7460-80a5-76cf344f932e-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 148, 'output_tokens': 8, 'total_tokens': 156, 'input_token_details': {'cache_read': 0}})]}
# The weather in Delhi is Sunny ☀️
# {'messages': [HumanMessage(content='Add 32 and 2', additional_kwargs={}, response_metadata={}, id='b76e8757-c45f-4791-916e-00a6f8545b5e'), AIMessage(content='', additional_kwargs={'function_call': {'name': 'add', 'arguments': '{"a": 32, "b": 2}'}, '__gemini_function_call_thought_signatures__': {'b49c1c74-f458-4baa-bfef-42d96581a2b6': ''}}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f2817-7ec0-7362-a287-93b272ac2c36-0', tool_calls=[{'name': 'add', 'args': {'a': 32, 'b': 2}, 'id': 'b49c1c74-f458-4baa-bfef-42d96581a2b6', 'type': 'tool_call'}], invalid_tool_calls=[], usage_metadata={'input_tokens': 111, 'output_tokens': 83, 'total_tokens': 194, 'input_token_details': {'cache_read': 0}, 'output_token_details': {'reasoning': 64}}), ToolMessage(content='34', name='add', id='6e567040-727b-4da5-87be-9e6659620427', tool_call_id='b49c1c74-f458-4baa-bfef-42d96581a2b6'), AIMessage(content='The sum of 32 and 2 is 34.', additional_kwargs={}, response_metadata={'finish_reason': 'STOP', 'model_name': 'gemini-2.5-flash', 'safety_ratings': [], 'model_provider': 'google_genai'}, id='lc_run--019f2817-8462-72b2-bcb0-25fc29996210-0', tool_calls=[], invalid_tool_calls=[], usage_metadata={'input_tokens': 144, 'output_tokens': 14, 'total_tokens': 158, 'input_token_details': {'cache_read': 0}})]}
# The sum of 32 and 2 is 34.
